# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./synthetic_healthcare_300k.csv')


df.head()
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# 0     Allison Hill   69  Female        AB-           Obesity
# 1      Noah Rhodes   32  Female        AB-           Obesity
# 2  Angie Henderson   89  Female         B+          Diabetes
# 3    Daniel Wagner   78  Female         O-            Cancer
# 4  Cristian Santos   38    Male         O-            Cancer
#
#                  Doctor                              Hospital  \
# 0    Dr. Raymond Willis                    Davis PLC Hospital
# 1   Dr. Hannah Thompson                Vaughn-Martin Hospital
# 2   Dr. Amber Velazquez  Wade, Williams and Ferguson Hospital
# 3   Dr. Matthew Oconnor                     Mata Ltd Hospital
# 4  Dr. Alexandra Massey                    Berry LLC Hospital
#
#   Insurance Provider  Billing Amount  Room Number Admission Type   Medication  \
# 0              Cigna        43185.95         6656      Emergency    Metformin
# ...

# %%
df.describe()
# Out:
#                  Age  Billing Amount    Room Number
# count  300000.000000   300000.000000  300000.000000
# mean       53.940400    25208.924657    5053.145697
# std        21.064025    14271.122048    2857.771650
# min        18.000000      500.160000     100.000000
# 25%        36.000000    12874.395000    2577.000000
# 50%        54.000000    25182.160000    5047.000000
# 75%        72.000000    37560.480000    7533.000000
# max        90.000000    49999.540000    9999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Name                300000 non-null  object
#  1   Age                 300000 non-null  int64
#  2   Gender              300000 non-null  object
#  3   Blood Type          300000 non-null  object
#  4   Medical Condition   300000 non-null  object
#  5   Doctor              300000 non-null  object
#  6   Hospital            300000 non-null  object
#  7   Insurance Provider  300000 non-null  object
#  8   Billing Amount      300000 non-null  float64
#  9   Room Number         300000 non-null  int64
#  10  Admission Type      300000 non-null  object
#  11  Medication          300000 non-null  object
#  12  Test Results        300000 non-null  object
#  13  Date of Admission   300000 non-null  object
#  14  Discharge Date      300000 non-null  object
# ...

# %%
for c in df.columns:
    print(f'{c}: {df[c].nunique()} unique values')
# Out:
# Name: 159089 unique values
# Age: 73 unique values
# Gender: 2 unique values
# Blood Type: 8 unique values
# Medical Condition: 6 unique values
# Doctor: 159248 unique values
# Hospital: 183010 unique values
# Insurance Provider: 5 unique values
# Billing Amount: 291058 unique values
# Room Number: 9900 unique values
# Admission Type: 3 unique values
# Medication: 7 unique values
# Test Results: 3 unique values
# Date of Admission: 300000 unique values
# Discharge Date: 300000 unique values

# %%
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[24], line 15
#       4 url = URL.create(
#       5     "postgresql+psycopg2",
#       6     username="postgres",
#    (...)     10     database="hospital_project",
#      11 )
#      13 engine = create_engine(url)
# ---> 15 df.to_sql(
#      16     name="Hospital_data",
#      17     con=engine,
#      18     schema="public",
#      19     if_exists="fail",  # or 'replace'
#      20     index=False
#      21 )
#
# File c:\ProgramData\anaconda3\envs\myenv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
# ...
